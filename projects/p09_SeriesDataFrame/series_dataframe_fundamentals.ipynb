# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset("Titanic")

# %%
print(df.head())

# %%
print(df.tail())

# %%
print(f"Rows: {df.shape[0]} & Columns: {df.shape[1]}")

# %%
print(df.dtypes)

# %%
print(df.info())

# %%
print(df.describe())

# %%
sex_series = pd.Series(df["sex"])
print(sex_series)

# %%
sex_df = df[["sex"]]
print(sex_df)

# %%
type(sex_series)
#pandas.core.series.Series

print(sex_series.size) #891

# %%
type(sex_df)
#pandas.core.frame.DataFrame

sex_df.size #891
